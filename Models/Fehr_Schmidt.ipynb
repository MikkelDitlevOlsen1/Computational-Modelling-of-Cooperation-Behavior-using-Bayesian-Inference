# %%
import os 
# Go one folder back
os.chdir('..')
from Python_scripts.data_processing import *
from Python_scripts.log_likelihood import *
# Out:
# /Users/danyu/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/danyu/Documents/DTU/Bachelorprojekt/Bachelor_project/Python_scripts/data_processing.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ug_1['choose'][ug_1.choose != '�ܾ�'] = 1
# /Users/danyu/Documents/DTU/Bachelorprojekt/Bachelor_project/Python_scripts/data_processing.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ug_1['choose'][ug_1.choose == '�ܾ�'] = 0

# %%
l = formels()
l.acceptance_prob(1, 1, 1, 1,a=0.5,propabelety_func = "g_log")
# Out:
# 0.5004555255972003

# %%
subjects_dataframe, subjects_dataframe_gain, subjects_dataframe_loss = data_processing_func()
# Out:
# /Users/danyu/Documents/DTU/Bachelorprojekt/Bachelor_project/Python_scripts/data_processing.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ug_1['choose'][ug_1.choose != '�ܾ�'] = 1
# /Users/danyu/Documents/DTU/Bachelorprojekt/Bachelor_project/Python_scripts/data_processing.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ug_1['choose'][ug_1.choose == '�ܾ�'] = 0

# %%
class All_persons():
    def __init__(self, Personrange, startegy):
        allpersons=[None]*len(Personrange)
        self.startegy=startegy
        for i in Personrange: 
            allpersons[i]=startegy(subjects_dataframe_gain[i],min_c=1,max_c=20,number_of_c = 10)
        self.allpersons=allpersons
        
    def plot_all(self):
        for person in self.allpersons:
            person.plot()

    def plot_all_x2(self):
        for person in self.allpersons:
            person.plot_x2()
            


    def get_person(self,person_nr):
        return self.allpersons[person_nr]

# %%
a=All_persons(range(77),Log_Likelihood)
# Out:
# 1    48
# Name: Subject, dtype: int64
# 48    63
# Name: Subject, dtype: int64
# 95    123
# Name: Subject, dtype: int64
# 142    132
# Name: Subject, dtype: int64
# 189    137
# Name: Subject, dtype: int64
# 236    138
# Name: Subject, dtype: int64
# 283    147
# Name: Subject, dtype: int64
# 330    149
# Name: Subject, dtype: int64
# 377    152
# Name: Subject, dtype: int64
# 424    157
# Name: Subject, dtype: int64
# 471    164
# Name: Subject, dtype: int64
# 518    165
# Name: Subject, dtype: int64
# 565    168
# Name: Subject, dtype: int64
# 612    171
# Name: Subject, dtype: int64
# 659    172
# Name: Subject, dtype: int64
# 706    174
# Name: Subject, dtype: int64
# 753    177
# Name: Subject, dtype: int64
# 800    179
# Name: Subject, dtype: int64
# 847    180
# Name: Subject, dtype: int64
# 894    182
# Name: Subject, dtype: int64
# 941    185
# Name: Subject, dtype: int64
# 988    188
# Name: Subject, dtype: int64
# 1035    189
# Name: Subject, dtype: int64
# 1082    191
# Name: Subject, dtype: int64
# 1129    193
# Name: Subject, dtype: int64
# 1176    195
# Name: Subject, dtype: int64
# 1223    196
# Name: Subject, dtype: int64
# 1270    200
# Name: Subject, dtype: int64
# 1317    201
# Name: Subject, dtype: int64
# 1364    203
# Name: Subject, dtype: int64
# 1411    206
# Name: Subject, dtype: int64
# 1458    213
# Name: Subject, dtype: int64
# 1505    216
# Name: Subject, dtype: int64
# 1552    218
# Name: Subject, dtype: int64
# 1599    219
# Name: Subject, dtype: int64
# 1646    220
# Name: Subject, dtype: int64
# 1693    221
# Name: Subject, dtype: int64
# 1740    227
# Name: Subject, dtype: int64
# 1787    232
# Name: Subject, dtype: int64
# 1834    234
# Name: Subject, dtype: int64
# 1881    238
# Name: Subject, dtype: int64
# 1928    247
# Name: Subject, dtype: int64
# 1975    250
# Name: Subject, dtype: int64
# 2022    260
# Name: Subject, dtype: int64
# 2069    261
# Name: Subject, dtype: int64
# 2116    262
# Name: Subject, dtype: int64
# 2163    264
# Name: Subject, dtype: int64
# 2210    266
# Name: Subject, dtype: int64
# 2257    267
# Name: Subject, dtype: int64
# 2304    268
# Name: Subject, dtype: int64
# 2351    270
# Name: Subject, dtype: int64
# 2398    271
# Name: Subject, dtype: int64
# 2445    272
# Name: Subject, dtype: int64
# 2492    273
# Name: Subject, dtype: int64
# 2539    274
# Name: Subject, dtype: int64
# 2586    277
# Name: Subject, dtype: int64
# 2633    96
# Name: Subject, dtype: int64
# 3620    100
# Name: Subject, dtype: int64
# 3667    110
# Name: Subject, dtype: int64
# 3714    116
# Name: Subject, dtype: int64
# 3761    140
# Name: Subject, dtype: int64
# 3808    155
# Name: Subject, dtype: int64
# 3855    156
# Name: Subject, dtype: int64
# 3902    173
# Name: Subject, dtype: int64
# 3949    178
# Name: Subject, dtype: int64
# 3996    187
# Name: Subject, dtype: int64
# 4043    194
# Name: Subject, dtype: int64
# 4090    198
# Name: Subject, dtype: int64
# 4137    199
# Name: Subject, dtype: int64
# 4184    205
# Name: Subject, dtype: int64
# 4231    207
# Name: Subject, dtype: int64
# 4278    215
# Name: Subject, dtype: int64
# 4325    236
# Name: Subject, dtype: int64
# 4372    241
# Name: Subject, dtype: int64
# 4419    257
# Name: Subject, dtype: int64
# 4466    259
# Name: Subject, dtype: int64
# 4513    263
# Name: Subject, dtype: int64

# %%
a.plot_all_x2()
